# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data2018 = pd.read_csv('./data/2018.csv', sep=';', engine='c', encoding='437')

# %%
data2018
# Out:
# .
# 131870  Pelotizaç╞o ES - GER MANUT ELETRICA PELOTIZACA...
#
#                                            CARGO  \
# 0                                     Maquinista
# 1                           Maquinista de Viagem
# 2                                     Maquinista
# 3                                     Maquinista
# 4                                     Maquinista
# 5                Oficial de Operaçao Ferroviaria
# 6                             Tecnico Mecanico I
# 7            Controlador de Patio e Terminais II
# 8            Controlador de Patio e Terminais II
# 9                                    Mecanico II
# 10               Oficial de Operaçao Ferroviaria
# 11                                 Eletricista I
# 12                                 Eletricista I
# 13               Tecnico de Operaçao Ferroviaria
# 14                                    Maquinista
# 15                           Maquinista de Patio
# 16                           Maquinista de Patio
# ...

# %%
data2018.shape
# Out:
# (131871, 34)

# %%
semAcidentes = data2018[data2018['ACIDENTES'] == 0]

# %%
semAcidentes
# Out:
# .
# 131870  Pelotizaç╞o ES - GER MANUT ELETRICA PELOTIZACA...
#
#                                            CARGO  \
# 0                                     Maquinista
# 1                           Maquinista de Viagem
# 2                                     Maquinista
# 3                                     Maquinista
# 4                                     Maquinista
# 5                Oficial de Operaçao Ferroviaria
# 6                             Tecnico Mecanico I
# 7            Controlador de Patio e Terminais II
# 8            Controlador de Patio e Terminais II
# 9                                    Mecanico II
# 10               Oficial de Operaçao Ferroviaria
# 11                                 Eletricista I
# 12                                 Eletricista I
# 13               Tecnico de Operaçao Ferroviaria
# 14                                    Maquinista
# 15                           Maquinista de Patio
# 16                           Maquinista de Patio
# ...

# %%
semAcidentes.shape
# Out:
# (123935, 34)

# %%
comAcidentes = data2018[data2018['ACIDENTES'] != 0]

# %%
comAcidentes.shape
# Out:
# (7936, 34)

# %%
maisAcidentes = data2018[data2018['ACIDENTES'] > 1]

# %%
maisAcidentes.head()
# Out:
#           DATA       ID                                         HIERARQUIA  \
# 33  01/01/2018    17681  Ferrovia ES - GER OPER FERROVIARIA II EFVM - S...
# 38  01/01/2018    32524  Ferrovia ES - GER OPER FERROVIARIA II EFVM - S...
# 40  01/01/2018    38737  Ferrovia ES - GER OPER FERROVIARIA II EFVM - S...
# 44  01/01/2018   291625  Ferrovia ES - GER OPER FERROVIARIA II EFVM - S...
# 50  01/01/2018  1508365  Ferrovia ES - GER OPER FERROVIARIA II EFVM - S...
#
#                               CARGO                     TURNO  IDADE  \
# 33                       Maquinista  Escala Padrao Maquinista     42
# 38                       Maquinista  Escala Padrao Maquinista     42
# 40                       Maquinista         Turno Revezamento     36
# 44                       Maquinista  Escala Padrao Maquinista     55
# 50  Oficial de Operaçao Ferroviaria         Turno Revezamento     37
#
#    ESTADO CIVIL  ACIDENTES DATA DE ADMISSAO  ESCORE         ...           \
# ...

# %%
sns.pairplot(maisAcidentes)

# %%
sns.scatterplot(x=maisAcidentes['CARGO'], y=maisAcidentes['ACIDENTES'])

# %%
acidentes2018 = data2018[data2018['DADOS DO ACIDENTE'] != 'SEM ACIDENTE NO ANO']

# %%
acidentes2018.shape
# Out:
# (1577, 34)

# %%
sns.scatterplot(x=acidentes2018['CARGO'], y=acidentes2018['IDADE'])

# %%
cat acidentes2018.csv | grep Maquinista | wc -l
# Out:
# 55

# %%
acidentes2018.to_csv('acidentes2018.csv')

# %%
cat data/2018.csv | grep Maquinista | wc -l
# Out:
# 16858

# %%
dataId = data2018['ID'].nunique()

# %%
alcoolDrogas = data2018[data2018["G1 P4"] != 0]

# %%
alcoolDrogas
# Out:
#               DATA      ID                                         HIERARQUIA  \
# 19955   17/01/2018  526977  Pelotizaç╞o ES - GER MANUT ELETRICA PELOTIZACA...
# 32244   29/01/2018  544364  Porto ES - GER OPERACAO MFE PORT SUDESTE - Sup...
# 70193   28/02/2018  308882  Ferrovia ES - GER OPER FERROVIARIA II EFVM - S...
# 81765   09/03/2018  493109  Pelotizaç╞o ES - GER MANUT GDES REPAROS PELOTI...
# 88131   14/03/2018  526977  Pelotizaç╞o ES - GER MANUT ELETRICA PELOTIZACA...
# 91451   16/03/2018  485432  Pelotizaç╞o ES - GER EQUIP MOVEIS PELOTIZACAO ...
# 102005  26/03/2018  554041  Pelotizaç╞o ES - GER EQUIP MOVEIS PELOTIZACAO ...
# 115474  05/04/2018  515008  Porto ES - GER MAN PREV CORR CG PORT SUD - Sup...
# 125025  13/04/2018  501421  Porto ES - GER OPER CARGA GER PORT SUDEST - Su...
# 128437  16/04/2018  472201  Ferrovia ES - GER MANUT VIA PERMAN EFVM SAB - ...
#
#                                                  CARGO  \
# ...

# %%
medicamentos
# Out:
#                        Tecnico Eletroeletronica I
# 601                  Controlador de Patio e Terminais II
# 750                                           Maquinista
# 919                  Controlador de Patio e Terminais II
# 951             Operador de Equipamento e Instalaçao III
# 1035                                          Mecanico I
# 1128                                 Maquinista de Patio
# 1193                Operador de Equipamento e Instalaçao
# 1244                 Controlador de Patio e Terminais II
# 1294                                          Maquinista
# 1311                         Tecnico Eletroeletronica II
# 1433                          Tecnico Eletroeletronica I
# 1541                                          Maquinista
# 1559                 Controlador de Patio e Terminais II
# 1583                                 Maquinista de Patio
# 1620                                          Maquinista
# 1692                                            Operador
# ...

# %%
medicamentosAcidentes = medicamentos[medicamentos['DADOS DO ACIDENTE'] != 'SEM ACIDENTE NO ANO']

# %%
medicamentosAcidentes
# Out:
# Empty DataFrame
# Columns: [DATA, ID, HIERARQUIA, CARGO, TURNO, IDADE, ESTADO CIVIL, ACIDENTES, DATA DE ADMISSAO, ESCORE, NIVEL, PIOR VARIAVEL, Variavel 1, Valor Variavel 1, Variavel 2, Valor Variavel 2, Variavel 3, Valor Variavel 3, Variavel 4, Valor Variavel 4, Variavel 5, Valor Variavel 5, G1 P1, G1 P2, G1 P3, G1 P4, G1 P5, G1 P6, G1 P7, G1 P8, G1 P9, G1 P10, FREQUENCIA DE ACESSO POR PERIODO, DADOS DO ACIDENTE]
# Index: []
#
# [0 rows x 34 columns]

# %%
medicamentosAcidentesTotal = medicamentos[medicamentos['ACIDENTES'] != 1]

# %%
medicamentosAcidentesTotal
# Out:
#                        Tecnico Eletroeletronica I
# 601                  Controlador de Patio e Terminais II
# 750                                           Maquinista
# 919                  Controlador de Patio e Terminais II
# 951             Operador de Equipamento e Instalaçao III
# 1035                                          Mecanico I
# 1128                                 Maquinista de Patio
# 1193                Operador de Equipamento e Instalaçao
# 1244                 Controlador de Patio e Terminais II
# 1294                                          Maquinista
# 1311                         Tecnico Eletroeletronica II
# 1433                          Tecnico Eletroeletronica I
# 1541                                          Maquinista
# 1559                 Controlador de Patio e Terminais II
# 1583                                 Maquinista de Patio
# 1620                                          Maquinista
# 1719              Operador de Equipamento e Instalaçao I
# ...

# %%
data2018.groupby('G1 P1')

# %%
medicamentos = data2018[data2018["G1 P5"] != 0]
